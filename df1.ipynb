# %%
import os
import shutil

# %%
def create_file():
    filename = input("Введите название файла: ")
    with open(filename, 'w') as file:
        print("Файл успешно создан")

def create_folder():
    foldername = input("Введите название папки: ")
    os.mkdir(foldername)
    print("Папка успешно создана")

def delete_item():
    itemname = input("Введите название файла или папки: ")
    if os.path.isfile(itemname):
        os.remove(itemname)
        print("Файл успешно удален")
    elif os.path.isdir(itemname):
        shutil.rmtree(itemname)
        print("Папка успешно удалена")
    else:
        print("Файл или папка не существует")

def move_item():
    itemname = input("Введите название файла или папки: ")
    destination = input("Введите путь для перемещения: ")
    shutil.move(itemname, destination)
    print("Файл или папка успешно перемещены")

def copy_item():
    itemname = input("Введите название файла или папки: ")
    destination = input("Введите путь для копирования: ")
    shutil.copy2(itemname, destination)
    print("Файл или папка успешно скопированы")
def show_menu():
    print("1. Создать файл")
    print("2. Создать папку")
    print("3. Удалить файл или папку")
    print("4. Переместить файл или папку")
    print("5. Скопировать файл или папку")
    print("0. Выход")

def main():
    show_menu()

    choice = input("Выберите пункт меню: ")

    while choice != "0":
        if choice == "1":
            create_file()
            pass
        elif choice == "2":
            create_folder()
            pass
        elif choice == "3":
            delete_item()
            pass
        elif choice == "4":
            move_item()
            pass
        elif choice == "5":
            copy_item()
            pass
        else:
            print("Неверный выбор")

        show_menu()
        choice = input("Выберите пункт меню: ")

# %%
main()
# Out:
# 1. Создать файл
# 2. Создать папку
# 3. Удалить файл или папку
# 4. Переместить файл или папку
# 5. Скопировать файл или папку
# 0. Выход
# Выберите пункт меню: 1
# Введите название файла: 23
# Файл успешно создан
# 1. Создать файл
# 2. Создать папку
# 3. Удалить файл или папку
# 4. Переместить файл или папку
# 5. Скопировать файл или папку
# 0. Выход
# Выберите пункт меню: 3
# Введите название файла или папки: 454
# Файл или папка не существует
# 1. Создать файл
# 2. Создать папку
# 3. Удалить файл или папку
# 4. Переместить файл или папку
# 5. Скопировать файл или папку
# 0. Выход
# Выберите пункт меню: 2
# Введите название папки: 33
# Папка успешно создана
# 1. Создать файл
# 2. Создать папку
# 3. Удалить файл или папку
# 4. Переместить файл или папку
# 5. Скопировать файл или папку
# 0. Выход
# Выберите пункт меню: 3
# Введите название файла или папки: 22
# Файл успешно удален
# 1. Создать файл
# 2. Создать папку
# 3. Удалить файл или папку
# 4. Переместить файл или папку
# ...
